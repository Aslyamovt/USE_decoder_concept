# %%
import sentencepiece as spm

s = spm.SentencePieceProcessor()
s.Load('D:/112/decoder/ru.wiki.bpe.vs200000.model')

text=[]
with open("D:\\112\\decoder\\news.txt", "r", encoding='utf-8') as fr:
    for line in fr:
        text.append(line)
print('Прочитано')

max = 0

pieces = []

for sen in text:
    a = s.EncodeAsIds(sen)
    if len(a)>max:
        max=len(a)
        print(max)
    pieces.append(a)
print('Закодировано')
# Out:
# Прочитано
# 16
# 22
# 68
# 129
# 155
# 158
# 208
# 230
# 231
# 354
# 366
# 1406
# 1508
# 1525
# 3306
# 5687
# 8214
# 11175
# Закодировано

# %%
i = -1
ids=[]
npi=[]
for a in pieces:
    i+=1
    if(len(a)>1024):
        ids.append(i)
        continue
    while(len(a)<1500):
        a.append(0)
    npi.append(a)
print('Расширено')

with open("D:\\112\\декодер\\news_pieces.txt", "w", encoding='utf-8') as fw:
    for vec in result:
        fw.write(str(vec[0]))
        for i in range(1,len(vec)):
            fw.write('\t'+ str(vec[i]))
        fw.write('\n')
print('Записано')
print(ids)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-75d37b5ce8fc> in <module>
#       7         ids.append(i)
#       8         continue
# ----> 9     while(len(a)<1500):
#      10         a.append(0)
#      11     npi.append(a)
#
# KeyboardInterrupt:

# %%
i = -1
ids=[]
npi=[]
for a in pieces:
    i+=1
    if(i%50000==0):
        print(i)
    if(len(a)>1024):
        ids.append(i)
        continue
    while(len(a)<1024):
        a.append(0)
    npi.append(a)    
print('Расширено')

with open("D:\\112\\декодер\\news_pieces.txt", "w", encoding='utf-8') as fw:
    for vec in npi:
        fw.write(str(vec[0]))
        for i in range(1,len(vec)):
            fw.write('\t'+ str(vec[i]))
        fw.write('\n')
print('Записано')
print(ids)
# Out:
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# 300000
# 350000
# 400000
# 450000
# 500000
# 550000
# 600000
# 650000
# 700000
# 750000
# 800000
# 850000
# 900000
# 950000
# 1000000
# 1050000
# 1100000
# 1150000
# 1200000
# 1250000
# 1300000
# 1350000
# 1400000
# 1450000
# 1500000
# 1550000
# 1600000
# 1650000
# 1700000
# 1750000
# 1800000
# 1850000
# 1900000
# 1950000
# 2000000
# 2050000
# 2100000
# 2150000
# 2200000
# 2250000
# 2300000
# 2350000
# 2400000
# 2450000
# 2500000
# 2550000
# 2600000
# 2650000
# 2700000
# 2750000
# 2800000
# 2850000
# 2900000
# 2950000
# 3000000
# 3050000
# 3100000
# 3150000
# 3200000
# 3250000
# 3300000
# 3350000
# 3400000
# 3450000
# 3500000
# 3550000
# 3600000
# 3650000
# 3700000
# 3750000
# 3800000
# 3850000
# 3900000
# 3950000
# 4000000
# 4050000
# 4100000
# 4150000
# 4200000
# 4250000
# 4300000
# 4350000
# 4400000
# 4450000
# 4500000
# 4550000
# 4600000
# 4650000
# 4700000
# 4750000
# 4800000
# 4850000
# 4900000
# 4950000
# 5000000
# 5050000
# 5100000
# 5150000
# 5200000
# 5250000
# 5300000
# 5350000
# 5400000
# 5450000
# 5500000
# 5550000
# 5600000
# 5650000
# 5700000
# 5750000
# 5800000
# 5850000
# 5900000
# 5950000
# 6000000
# 6050000
# 6100000
# 6150000
# 6200000
# 6250000
# 6300000
# 6350000
# 6400000
# 6450000
# 6500000
# 6550000
# 6600000
# 6650000
# 6700000
# 6750000
# 6800000
# 6850000
# 6900000
# 6950000
# 7000000
# 7050000
# 7100000
# 7150000
# 7200000
# 7250000
# 7300000
# 7350000
# 7400000
# 7450000
# 7500000
# 7550000
# 7600000
# 7650000
# 7700000
# 7750000
# 7800000
# 7850000
# 7900000
# 7950000
# 8000000
# 8050000
# 8100000
# 8150000
# 8200000
# 8250000
# 8300000
# 8350000
# 8400000
# 8450000
# 8500000
# 8550000
# 8600000
# 8650000
# 8700000
# 8750000
# 8800000
# 8850000
# 8900000
# 8950000
# 9000000
# 9050000
# 9100000
# 9150000
# 9200000
# 9250000
# 9300000
# 9350000
# 9400000
# 9450000
# 9500000
# 9550000
# 9600000
# 9650000
# 9700000
# 9750000
# 9800000
# 9850000
# 9900000
# 9950000
# 10000000
# 10050000
# 10100000
# 10150000
# 10200000
# 10250000
# 10300000
# 10350000
# 10400000
# 10450000
# 10500000
# 10550000
# 10600000
# 10650000
# 10700000
# 10750000
# 10800000
# 10850000
# 10900000
# 10950000
# 11000000
# 11050000
# 11100000
# 11150000
# 11200000
# 11250000
# 11300000
# 11350000
# 11400000
# 11450000
# 11500000
# 11550000
# 11600000
# 11650000
# 11700000
# 11750000
# 11800000
# 11850000
# 11900000
# 11950000
# 12000000
# 12050000
# 12100000
# 12150000
# 12200000
# 12250000
# 12300000
# 12350000
# 12400000
# 12450000
# 12500000
# 12550000
# 12600000
# 12650000
# 12700000
# 12750000
# 12800000
# 12850000
# 12900000
# 12950000
# 13000000
# 13050000
# 13100000
# 13150000
# 13200000
# 13250000
# 13300000
# 13350000
# 13400000
# 13450000
# 13500000
# 13550000
# 13600000
# 13650000
# 13700000
# 13750000
# 13800000
# 13850000
# 13900000
# 13950000
# 14000000
# 14050000
# 14100000
# 14150000
# 14200000
# 14250000
# 14300000
# 14350000
# 14400000
# 14450000
# 14500000
# 14550000
# 14600000
# 14650000
# 14700000
# 14750000
# 14800000
# Расширено
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-6cf74964cb9f> in <module>
#      14 print('Расширено')
#      15
# ---> 16 with open("D:\\112\\декодер\\news_pieces.txt", "w", encoding='utf-8') as fw:
#      17     for vec in npi:
#      18         fw.write(str(vec[0]))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\112\\декодер\\news_pieces.txt'

# %%
print(len(ids))
# Out:
# 1376011

# %%
with open("D:\\112\\decoder\\news_pieces.txt", "w", encoding='utf-8') as fw:
    for vec in npi:
        fw.write(str(vec[0]))
        for i in range(1,len(vec)):
            fw.write('\t'+ str(vec[i]))
        fw.write('\n')
print('Записано')

with open("D:\\112\\decoder\\id.txt", "w", encoding='utf-8') as fw:
    for id in ids:
        fw.write(str(id)+'\n')
# Out:
# Записано
